# %% [markdown]
# ## Pulling in Raw data into Dataframes

# %%
# Create import files

import pandas as pd
from pathlib import Path
import numpy as np
# %matplotlib inline

# %%
# Set the CSV to use as Path Class

closing_prices_path = Path("Closing prices.csv")
ESG_path = Path("barrons_ESG_everyone.csv")
financial_path = Path("FinancialAnalysis_withtickers.csv")
barron_path = Path("barrons_tickers_Morningstars.csv")

# %%
# Import CSV into Dataframe

closing_prices = pd.read_csv(closing_prices_path, index_col="Dates", parse_dates=True, infer_datetime_format=True)
ESG_data = pd.read_csv(ESG_path, index_col="Ticker", parse_dates=True, infer_datetime_format=True)
financial_data = pd.read_csv(financial_path, index_col="Tickers", parse_dates=True, infer_datetime_format=True)
barron_data= pd.read_csv(barron_path, index_col="Ticker", parse_dates=True, infer_datetime_format=True)

# %% [markdown]
# ## Check Dataframes

# %%
# Checking Dataframes

# closing_prices.head()
# ESG_data.head()
# barron_data.head()

# financial_data.head()

# %% [markdown]
# ## Drop Null Values

# %%
# Drop Appropiate columns
# Drop Null Values
closing_fixed = closing_prices.dropna(axis = 'columns')
ESG_fixed = ESG_data.dropna()

# financial_data.isnull().sum()

financial_clean = financial_data.dropna()

del financial_clean['Weight (%)']

# %% [markdown]
# ## Rename Columns

# %%
# Rename the columns


closing_fixed.columns = closing_fixed.columns.str.replace(r'us equity', '')

barron_data.columns = ['Name','10 year return', 'Dividend Yield TTM', 'Morningstar Risk', 'Turnover Ratio', 'SEC Dividend Yield', 'Morningstar Rating','Fund Category', 'Standard Deviation 3 year']

# %%
barron_data.head()
# Out:
#                                    Name  10 year return  Dividend Yield TTM  \
# Ticker
# AMFEX                       AAMA Equity             NaN                0.87
# AUIAX                AB Equity Income A            9.28                2.91
# FDSAX   AIG Focused Dividend Strategy A            9.39                3.95
# AKRIX                  Akre Focus Instl           16.95                0.00
# AMAGX             Amana Growth Investor           12.47                0.37
#
#        Morningstar Risk  Turnover Ratio  SEC Dividend Yield  \
# Ticker
# AMFEX               NaN            20.0                 NaN
# AUIAX     Below Average            43.0                2.18
# FDSAX           Average            37.0                3.20
# AKRIX               Low             3.0                 NaN
# AMAGX               Low             0.0                0.40
#
#         Morningstar Rating Fund Category  Standard Deviation 3 year
# Ticker
# AMFEX                  NaN   Large Blend                        NaN
# AUIAX                  4.0   Large Value                      16.13
# FDSAX                  3.0   Large Value                      19.02
# AKRIX                  5.0  Large Growth                      14.20
# AMAGX                  4.0  Large Growth                      15.04

# %%
barron_data = barron_data.dropna(subset=['10 year return'])

# %%
barron_data.head()
# Out:
#                                           Name  10 year return  \
# Ticker
# AUIAX                       AB Equity Income A            9.28
# FDSAX          AIG Focused Dividend Strategy A            9.39
# AKRIX                         Akre Focus Instl           16.95
# AMAGX                    Amana Growth Investor           12.47
# BRLVX   American Beacon Bridgeway Lg Cp Val R5            8.51
#
#         Dividend Yield TTM Morningstar Risk  Turnover Ratio  \
# Ticker
# AUIAX                 2.91    Below Average            43.0
# FDSAX                 3.95          Average            37.0
# AKRIX                 0.00              Low             3.0
# AMAGX                 0.37              Low             0.0
# BRLVX                 2.47    Above Average            44.0
#
#         SEC Dividend Yield  Morningstar Rating Fund Category  \
# Ticker
# AUIAX                 2.18                 4.0   Large Value
# FDSAX                 3.20                 3.0   Large Value
# AKRIX                  NaN                 5.0  Large Growth
# AMAGX                 0.40                 4.0  Large Growth
# BRLVX                  NaN                 3.0   Large Value
#
#         Standard Deviation 3 year
# Ticker
# AUIAX                       16.13
# FDSAX                       19.02
# AKRIX                       14.20
# AMAGX                       15.04
# BRLVX                       21.02

# %%
del barron_data['SEC Dividend Yield']
del barron_data['Standard Deviation 3 year']

# %%
barron_data.head()
# Out:
#                                           Name  10 year return  \
# Ticker
# AUIAX                       AB Equity Income A            9.28
# FDSAX          AIG Focused Dividend Strategy A            9.39
# AKRIX                         Akre Focus Instl           16.95
# AMAGX                    Amana Growth Investor           12.47
# BRLVX   American Beacon Bridgeway Lg Cp Val R5            8.51
#
#         Dividend Yield TTM Morningstar Risk  Turnover Ratio  \
# Ticker
# AUIAX                 2.91    Below Average            43.0
# FDSAX                 3.95          Average            37.0
# AKRIX                 0.00              Low             3.0
# AMAGX                 0.37              Low             0.0
# BRLVX                 2.47    Above Average            44.0
#
#         Morningstar Rating Fund Category
# Ticker
# AUIAX                  4.0   Large Value
# FDSAX                  3.0   Large Value
# AKRIX                  5.0  Large Growth
# AMAGX                  4.0  Large Growth
# BRLVX                  3.0   Large Value

# %%
barron_clean = barron_data.drop(['barrons_tickers'])

# %%
barron_clean.isnull().sum()
# Out:
# Name                  0
# 10 year return        0
# Dividend Yield TTM    0
# Morningstar Risk      0
# Turnover Ratio        0
# Morningstar Rating    0
# Fund Category         0
# dtype: int64

# %% [markdown]
# ## Correctly Formatted Dataframes for Team

# %%
ESG_fixed.head()
# Out:
#                                           Name     E      S     G  \
# Ticker
# AUIAX                       AB Equity Income A  4.80  11.02  8.35
# FDSAX          AIG Focused Dividend Strategy A  5.59  10.89  7.62
# AKRIX                         Akre Focus Instl  2.77   9.97  8.04
# AMAGX                    Amana Growth Investor  3.26   9.60  6.95
# BRLVX   American Beacon Bridgeway Lg Cp Val R5  5.68  10.78  8.08
#
#         Average (Current)
# Ticker
# AUIAX               24.38
# FDSAX               24.10
# AKRIX               20.91
# AMAGX               21.04
# BRLVX               24.53

# %%
closing_fixed.head()
# Out:
#              MXXVX    VLCGX    MIGFX    UMLGX      MGK    VIGRX    CSIEX   \
# Dates
# 2010-01-01    11.83    10.04    13.43    10.14  41.8700    27.32    30.53
# 2010-01-04    12.01    10.22    13.59    10.23  42.4699    27.76    30.97
# 2010-01-05    12.07    10.24    13.57    10.27  42.5700    27.84    31.09
# 2010-01-06    12.04    10.25    13.55    10.28  42.5200    27.84    31.12
# 2010-01-07    12.10    10.23    13.57    10.28  42.5800    27.89    31.18
#
#              WLGAX    POGAX    BIAFX   ...   SSHFX    HRCVX    FBCVX   \
# Dates                                  ...
# 2010-01-01    11.40    14.02     7.84  ...    28.58    12.06     9.96
# 2010-01-04    11.58    14.26     7.93  ...    29.10    12.22    10.20
# 2010-01-05    11.61    14.30     7.97  ...    29.20    12.23    10.29
# 2010-01-06    11.58    14.31     7.98  ...    29.32    12.27    10.33
# 2010-01-07    11.62    14.38     8.02  ...    29.50    12.30    10.43
#
#              NNGRX    TORYX    FDSAX    YAFFX    YACKX   SPX index  GSIN index
# Dates
# 2010-01-01    17.13    26.76     9.98    16.13    15.22    1115.10       72.81
# 2010-01-04    17.45    27.08    10.12    16.33    15.41    1132.98       74.05
# 2010-01-05    17.52    27.07    10.14    16.33    15.41    1136.52       74.24
# 2010-01-06    17.58    27.11    10.13    16.31    15.40    1137.14       74.19
# 2010-01-07    17.68    27.30    10.15    16.32    15.42    1141.70       74.08
#
# [5 rows x 133 columns]

# %%
barron_clean.head()
# Out:
#                                           Name  10 year return  \
# Ticker
# AUIAX                       AB Equity Income A            9.28
# FDSAX          AIG Focused Dividend Strategy A            9.39
# AKRIX                         Akre Focus Instl           16.95
# AMAGX                    Amana Growth Investor           12.47
# BRLVX   American Beacon Bridgeway Lg Cp Val R5            8.51
#
#         Dividend Yield TTM Morningstar Risk  Turnover Ratio  \
# Ticker
# AUIAX                 2.91    Below Average            43.0
# FDSAX                 3.95          Average            37.0
# AKRIX                 0.00              Low             3.0
# AMAGX                 0.37              Low             0.0
# BRLVX                 2.47    Above Average            44.0
#
#         Morningstar Rating Fund Category
# Ticker
# AUIAX                  4.0   Large Value
# FDSAX                  3.0   Large Value
# AKRIX                  5.0  Large Growth
# AMAGX                  4.0  Large Growth
# BRLVX                  3.0   Large Value

# %%
financial_clean.head()
# Out:
#                          Name  P/E Forward   P/B    ROA    ROE  \
# Tickers
# AMFEX             AAMA Equity        16.21  2.81   9.91  28.25
# AUIAX      AB Equity Income A        13.37  1.97   8.47  28.10
# FDSAX    AIG Focused Dividend        10.79  2.23   5.90  23.64
# AKRIX        Akre Focus Instl        29.46  6.75  10.37  40.51
# AMAGX    Amana Growth Investo        23.53  7.27  14.04  40.37
#
#          Projected EPS Growth (%)  Yield (%) Market Cap($ mil)
# Tickers
# AMFEX                        9.79       0.87        114,361.73
# AUIAX                        8.01       2.91         95,224.17
# FDSAX                        7.17       3.95         50,471.18
# AKRIX                       12.77       0.00         62,286.32
# AMAGX                       10.65       0.37         83,714.94

# %% [markdown]
# ## Concat ESG and Financial Metrics and Barron

# %%
esg_fm_barron = pd.concat([barron_clean.drop(columns = "10 year return", inplace = False),ESG_fixed.drop(columns = 'Name',inplace = False), financial_clean.drop(columns = 'Name',inplace = False)], axis = 'columns', join = 'inner')

# %%
esg_fm_barron
# Out:
#                                          Name  Dividend Yield TTM  \
# AUIAX                      AB Equity Income A                2.91
# FDSAX         AIG Focused Dividend Strategy A                3.95
# AKRIX                        Akre Focus Instl                0.00
# AMAGX                   Amana Growth Investor                0.37
# BRLVX  American Beacon Bridgeway Lg Cp Val R5                2.47
# ...                                       ...                 ...
# VWUSX             Vanguard US Growth Investor                0.26
# SRVEX             Victory Diversified Stock A                0.34
# WPVLX           Weitz Partners Value Investor                0.00
# WVALX                    Weitz Value Investor                0.00
# EGOIX         Wells Fargo Large Cap Core Inst                2.09
#
#       Morningstar Risk  Turnover Ratio  Morningstar Rating Fund Category  \
# AUIAX    Below Average            43.0                 4.0   Large Value
# FDSAX          Average            37.0                 3.0   Large Value
# AKRIX              Low             3.0                 5.0  Large Growth
# AMAGX              Low             0.0                 4.0  Large Growth
# BRLVX    Above Average            44.0                 3.0   Large Value
# ...                ...             ...                 ...           ...
# VWUSX          Average            41.0                 4.0  Large Growth
# SRVEX    Above Average           132.0                 2.0   Large Blend
# WPVLX    Above Average            38.0                 1.0  Large Growth
# WVALX              Low            32.0                 2.0  Large Growth
# EGOIX    Above Average            45.0                 3.0   Large Blend
#
#           E      S     G  Average (Current)  P/E Forward   P/B    ROA    ROE  \
# AUIAX  4.80  11.02  8.35              24.38        13.37  1.97   8.47  28.10
# FDSAX  5.59  10.89  7.62              24.10        10.79  2.23   5.90  23.64
# AKRIX  2.77   9.97  8.04              20.91        29.46  6.75  10.37  40.51
# AMAGX  3.26   9.60  6.95              21.04        23.53  7.27  14.04  40.37
# BRLVX  5.68  10.78  8.08              24.53        12.79  1.86   5.64  16.84
# ...     ...    ...   ...                ...          ...   ...    ...    ...
# VWUSX  2.46  11.25  8.08              22.81        28.46  7.08   8.86  24.78
# SRVEX  2.91   9.89  7.21              23.79        13.27  2.39   9.58  27.60
# WPVLX  3.09   8.57  8.13              22.97        17.44  1.71   8.24  21.42
# WVALX  2.75   9.87  8.92              21.23        18.76  2.07   8.84  23.70
# EGOIX  3.86  10.79  7.37              22.78        13.04  2.08  10.18  31.32
#
#        Projected EPS Growth (%)  Yield (%) Market Cap($ mil)
# AUIAX                      8.01       2.91         95,224.17
# FDSAX                      7.17       3.95         50,471.18
# AKRIX                     12.77       0.00         62,286.32
# AMAGX                     10.65       0.37         83,714.94
# BRLVX                      8.09       2.47         36,213.84
# ...                         ...        ...               ...
# VWUSX                     13.20       0.26        101,064.40
# SRVEX                     12.18       0.34         59,605.06
# WPVLX                     12.22       0.00         22,862.80
# WVALX                     10.54       0.00         83,737.60
# EGOIX                      8.81       2.09         64,199.03
#
# [131 rows x 17 columns]

# %% [markdown]
# ## Performance anaylsis

# %%
esg_fm_barron
